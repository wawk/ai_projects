# %%
## Introduction to Tensors
## Creating Tensors
## PyTorch tensors are created using torch.Tensor() = https://pytorch.org/docs/stable/tensors.html
#Scalar
import torch
import pandas as pd
import numpy as np
print(torch.__version__)
scalar = torch.tensor(7)
# Out:
# 2.10.0+cpu

# %%
scalar
# Out:
# tensor(7)

# %%
scalar.ndim
# Out:
# 0

# %%
scalar.item()
# Out:
# 7

# %%
# Vector
vector = torch.tensor([7, 7])
vector
# Out:
# tensor([7, 7])

# %%
# MATRIX
MATRIX = torch.tensor([[7, 8], [1, 4]])

# %%
MATRIX.ndim
# Out:
# 2

# %%
MATRIX[0, 1]
# Out:
# tensor(8)

# %%
# TENSOR
