# %%
# Installl all required packages
# --- Install core agentic AI packages ---
# !pip install -q langchain langgraph langchain-openai

# --- Install visualization tools ---
# !pip install -q graphviz pydot
# !apt-get update -qq
# !apt-get install -y graphviz graphviz-dev pkg-config
# !pip install pygraphviz
# !pip install pydot
# !pip install pydotplus
# !apt-get -qq install graphviz

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/ai_projects

# %%
#Load env from Drive
import os
from dotenv import load_dotenv

env_path = "/content/drive/MyDrive/ai_projects/.env"
load_dotenv(env_path)

print("Environment loaded:", os.path.exists(env_path))

# %%
# Verify OpenAI key is available
import os

key = os.getenv("OPENAI_API_KEY")
print("Key loaded:", "Yes" if key else "No")

# %%
# Test LangChain + OpenAi client
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")
response = llm.invoke("Hello from your setup notebook!")
response

# %%
# Test LangGraph installation
from langgraph.graph import StateGraph, END

def node_fn(state):
    return {"msg": "LangGraph is working!"}

graph = StateGraph(dict)
graph.add_node("test", node_fn)
graph.set_entry_point("test")
graph.add_edge("test", END)

app = graph.compile()
app.invoke({})

# %%
#Test Graphviz rendering
from graphviz import Digraph

dot = Digraph()
dot.node("A", "Start")
dot.node("B", "End")
dot.edge("A", "B")

dot
